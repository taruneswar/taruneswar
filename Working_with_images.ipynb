# %% [markdown]
# <a href="https://colab.research.google.com/github/taruneswar/taruneswar/blob/main/Working_with_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
f=misc.face()
##this will import image from misc

# %%
f.shape
## 768 is L 1024 is B 3 is number of channels
# Out:
# (768, 1024, 3)

# %%
type(f)
# Out:
# numpy.ndarray

# %%
f
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(f)

# %%
a = f[384:,512:,:]
#Performing slicing operation

# %%
plt.imshow(a)
plt.show()

# %%
a1,a2 = np.split(f,2)

# %%
plt.imshow(a1)
plt.show()

# %%
plt.imshow(a2)
plt.show()

# %%
## Splitting image into half
b1,b2 = np.split(f,2,axis=1)

# %%
plt.imshow(b1)

# %%
plt.show()

# %%
plt.imshow(b2)

# %%
##now we can combine both the images which are divided into half
plt.imshow(np.concatenate((a1,a2)))
